# %% [markdown]
# ### Usage
#
# The **BitTorrent client** can be used in two ways: as a command-line script or imported as a package into other Python code.
#
# #### Running as a Script
# When run as a script, you can pass command-line arguments. The entry point is `__main__.py`. The `destination` argument is optional and defaults to the current directory from which the client is executed.
#
# ```python
# python -m torrentula --torr <your-torrent.torrent> --dest <download-directory>
# ```
#
# - --torr <your-torrent.torrent>: The path to the torrent file.
# - --dest <download-directory>: The directory where the files will be downloaded. If not specified, it defaults to the current directory.
#
# #### Importing as a Package
#
# You can also import the package programmatically into other Python code. In this case, __main__.py is ignored, and __init__.py is invoked, exposing the functions imported inside __init__.py to the scope of your code.
#
# ```python
# import torrentula
# torrentula.download_torrent(<your-torrent.torrent>, <download-directory>)
# ```
# This method allows for integration of the torrent client directly within Python applications.

# %% [markdown]
# ### Development
#
# #### Running Tests
# The library tests can be automatically discovered and ran by the unittests library. Example torrents for testing are in the fixtures folder.
# ```python
# python -m unittest discover
# ```

# %% [markdown]
# ### Examples

# %%
# !cd .. && pwd
# Out:
# /Users/kevin/Documents/umd/cmsc417/CMSC417/final-project

# %%
# This file is in docs subdirectory so first navigate to project home directory. 
# !cd .. && python -m torrentula --torr tests/fixtures/debian-mac.torrent
# Out:
# INFO:torrentula.log:Arguments validated successfully.
# DEBUG:torrentula.log:Torrent 'tests/fixtures/debian-mac.torrent' decoded:
# DEBUG:torrentula.log:{b'announce': b'http://bttracker.debian.org:6969/announce', b'comment': b'"Debian CD from cdimage.debian.org"', b'created by': b'mktorrent 1.1', b'creation date': 1731156221, b'info': {b'length': 659554304, b'name': b'debian-mac-12.8.0-amd64-netinst.iso', b'piece length': 262144, b'pieces': b'm(z\xac\xab\xc3\xa64\x87\x04)I\x8f\x0el\x1a\x92>\x96P\xe3\xbb\x1e\xd2\xe5}<\xe8]\xd2\xcb\xa9d/\x0c\xe2\x8a\x91\xc6\x1aQZC\xb3\x10d\x9b\xb64\x08\x90\xac;\xc3\xfb\xd1*\xa7M\xee:D\xb3\xaf\x8e\xa6Sz\x8ah4Y*\xa3\x9f\xca\x17V]X\x8aX\x06\\~T\xd0\xd6\xa8\xfd`\x9a\x04\xe51"I\x8a\x83\x9f\xaf\x01!\xb0\xab\x96\x93d\xa4H\xa91\x90\xd01\x8b\xf4\xc8\xae\xe2\xb4\xbc\x80\x04\x10\xcc\xfaL&\x0f0\x93\xfb\x94\x96\xba\x9b\x1eh\xa1\xf9\xb9\x82\xf7\xf5\xb2\xbfQ\xd5\xd6\xfe\xc3\xa5\xef+\xd9\xf2\x10\xd2>U\xe4\xc3\x88[\t\xc7\xaf\xec\x1a\xbc\x10\xf4\xb2\x0eJmV\xd5$\xa4=W\xf0\xfb\xce\xf6^\x85\xfa\x1b\xa2r\x0c\x8a8\xbb\xa3\xe1NL\x1f\x8d\xa5w*V\x02$(\xaa\x94aY\xf9\xc8i\xe3\x00C\xf8W\xd7\xea\xacu\x8d\xdeh\xab\xd8Fu\x7fW+\r\x08kM\xe6\x9f\xfb\x0b\x01\xf6\xc0\xa4\x1a\x96-hQ\'\xdb\xf8\x86\x9cR/\xefx\xaf\xa5\xf4\x9b\x9e\xf7\xfb\xb2\x88\x03\xf7\xa9\xcb\xb3\xf0\xdf\xe6\x19\xa4\x05BZ\x04\x1b()%(\x98E\xb2)\x15,\xc6\x87\xa2\x12\x91\xef\xdc\xb9f\xcd\xa0\xcb)i\xbd\xf6\xf1S\xe7\x8bt\xb8<\x97\t\x07(\xcfm\xba\xab[\xc9,8]\xfaF\x1d3d\xf7\x9c\xd8Zd\xe0\xf4W\xeb\x94>~\x93\x87\x16y\xcd\xb7^k\xcao\x04\xc4\xc7JL6\x95z\xb5[\x01OB\xf33K\xa9\xf7\xb5\xdbw\x8a<\xf6\xd5\xaa\x865\xc2b\x0c\xae\x902)\x82\xb3\xea\xc0\xe3\x02\x071\xd6t\xb1\xe5\xabq\x07>q\xcf@m\x1d\r\x92\x82\x9f\xbd\xd9\\\x8b\xaf\xeb\xc3\xa3O h\xfa`\xfb\x16S\xe8\x14z\x14\xd9\x1fn\xa2\xa5aSv_nR\xcf\xc1;h\x8e\xaa\xef\x18\xb0h\xf1X\x17\x93\xec\xf7.C\xc5A\xf2\xc6\x88|\xa6i\xc8\x85\x87\xbf\x04\xff\xf7F\x8e()E\xb4\xfb\x1c\xf8\x9a\xdc\x13\xacv\x1cvN\xc3\xc9\xac\xfd\xde\x13\x1b\xa2\xd5\xf2\x0b\xd5\x07&\x12l\xc2\xeb\xb4\xe7\x14\xd2\xc4c%\\$\x14\xaa\x8e\x80Wz\x90\x82\xad\xb2!\x96g\x015\xabr\x8d|\x1c\x8cE\xb6D<\x0c1kP30\x91\x13j\x88\x11<b\xacJ3\xab\xfdn\x98\xe8\x10\xb6\x9aX\xc9\x0f\x0b\x87R\x80\t\x8fu\xc4%\xba\xf7\x1e\xeab\xbaG\xe3j\xa5\xc1Y\x16^f)\xe5\xdf\x04&?\xfc\xe6\xc3\x08F"\xfd\x15\xb2F\x8bXJ\x9a\x91vETe#\x04\x01\xf8\xd5b-\x1b{~e\xbf\t \x19UP5\xf69lO\xf8I\x12f\x86\x01A(\xb9 \x11\xf6\x00T\x07\xed\xbb\xd9\x83\xb0\xbdh\x10\xd0<)\x1e\x8a\xc3\xe8\xc2v\xe4;!\x0c\xba\x08\xa5>\xf5n\x00Y}\xdd.\xa2+\xd0[4\xf9v\xca\xdf\xdc\x06\xf2\x9f\xf6(+\xac_\xc4\x13\xa5ei\xdds\x99\xd9:\xc6\xceE,\xd7%p\xefcz\x05\xb8\x87T\x96*\xef\xf7\xe0P\xb7|\x8ar\x00\nt\xf7\xb0\xe5-y\xcd\xd2Y*\xe6J\x88W\xde\xf1\xc6\n\xa4f\x93L\xc5\x8a\x87k\xd2D\x9b{\xf0*\x066\xbc\xd1\xa9\x86\xfe\xb3\x9dbtK=w\x01\xcd\x81\xd0\xf1Y\x82\xf1\xbd\x13\x16\x15\x87\xb3\xea\t\x07_M\xfdq\x83$\x04\xf2\x8bs\xf3\xd4>\x04\xe8$\xbc\x08\x18bS@\x15\x10\x04\xc3G$\xe7\xf5\xfb\xcc\x06%.\xc1\x11\xa3\x00E\xeb\n `\x83\x93\xc5u\x17\x13=\xabX(\xfas\x9e\x93k\x9e#ZM\xda\xf9u\x98\xf8\x96R-\xa5&\xdb\xec\xea;#\xd7(\xad8\xef9\xa1\x92\xc5\xe3\xa3\xc3\xa3\xcc<\x85.\xd8\x83,\xf2\x1f.\xda\x0b\xeb\x8f\xca\xcaD\xc7\x11\xd1\xa5k@\xa2\x1d\x0e\xe4\xd1l\x12\xad[+\xff)\x14\x12bs5\xeb\x0ch\x910\x9d\xab\x00\x1c\x968\xeb\x10\xb8\xed`\xa8\xf5\xfb!\x8e\x81\xe6\xc8K\xdb\xb8av\xca\xd3;\r\xd7\xf3~\xfd\x14\x93\xf3P\xef\x05Y\xe3q\xdcl\xe7\xb4\xe6\x12\xe8\xa7C\xab\xd1K)\xd7t\x00\xbf\x8e+\x0f\xab\xd2\xcb\x12~t\x90&\xad\x1e\x05\x02\x02!\xe4\xe2\x80\xc5\xe9E\xc9\xcd\x83\xa6\x01\x81Q\xf0`\xba\xb3\x18\x1db\x92\xce\xa1\xc8\x02\x18\xa9\xe8E\xa4\xc9\xe7\xe5L\xd9t}\xc8\xe4\x97h\x0e\xa2x\x1f\xa9\xe8\x19\xe3z\xf47kc:\x17\x15\x98r\xc7]\\\r\xd9/+\xf3\xa4\xfbfM\xf0\xe0\xbb\xb8J(\xe4\xab\\\xfd\x84\xd8\xf9+\\\xe2\x1c\xef\x11\xb1\xa8\x128\xdb\xa9}\x87D\xb1s\xf1P\x02\xa5\x96\xbb\xd4\xb8\xc0\xc7\xa19\xbd<\x81?E\x85\x0e_\x9f\xfc\x98\xb4kB\x80\xcc\xa7\xa4\x80\xd5-\x84\xbd\xc7\x9a+\x9b\x12\x0fU\xa6\xf6\xa5lM\xa3\x1b\xf0\x12<~\xf7\x86\'W\x1e\x08=\xd3\xf5\xca\xfb\xd7\xf2\x83R.f\x8e\x9a\xb7=\xddHG=~\x0eG\x96X\x8f\xd6\x96\x00\x0fL\xfao\x8d4\xd5U\xd5\xff~^FE\x92%2\t\\\xc9~\xd6\xf39\x87y\x06N\xeeC\xa0\x1a\xban\x93\x97\x16uZ\xfcM\x94/\x18M\xfe{k\xbc%\xdd\x17\ ...
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/kevin/Documents/umd/cmsc417/CMSC417/final-project/torrentula/__main__.py", line 15, in <module>
#     main()
#     ~~~~^^
#   File "/Users/kevin/Documents/umd/cmsc417/CMSC417/final-project/torrentula/__main__.py", line 11, in main
#     client.download_torrent(args.torr, args.dest)
#     ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kevin/Documents/umd/cmsc417/CMSC417/final-project/torrentula/core/client.py", line 80, in download_torrent
#     self.peers, rerequest_interval = self.tracker.join_swarm()
#                                      ^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Tracker' object has no attribute 'join_swarm'
